# %% [markdown]
# # Simulate Artificial Bee Colony (ABC) algorithm. Take sufficient test data; you may choose a problem of your choice to evaluate performance of ABC.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define Objective Function (Sphere Function)
def sphere(x):
    return np.sum(x ** 2)

# Artificial Bee Colony Algorithm
class ArtificialBeeColony:
    def __init__(self, func, n_dim=5, n_bees=30, limit=50, max_iter=200, lb=-5, ub=5):
        self.func = func
        self.n_dim = n_dim
        self.n_bees = n_bees
        self.limit = limit
        self.max_iter = max_iter
        self.lb = lb
        self.ub = ub

    def optimize(self):
        # Step 1: Initialize Food Sources
        food_sources = np.random.uniform(self.lb, self.ub, (self.n_bees, self.n_dim))
        fitness = np.array([self._fitness(self.func(x)) for x in food_sources])
        trial = np.zeros(self.n_bees)

        # Best solution tracking
        best_index = np.argmin([self.func(x) for x in food_sources])
        best_solution = food_sources[best_index].copy()
        best_value = self.func(best_solution)
        convergence_curve = []

        # Step 2: Iterations
        for it in range(self.max_iter):

            # Employed Bee Phase
            for i in range(self.n_bees):
                k = np.random.randint(0, self.n_bees)
                while k == i:
                    k = np.random.randint(0, self.n_bees)
                phi = np.random.uniform(-1, 1, self.n_dim)
                new_solution = food_sources[i] + phi * (food_sources[i] - food_sources[k])
                new_solution = np.clip(new_solution, self.lb, self.ub)
                new_value = self.func(new_solution)
                if self._fitness(new_value) > fitness[i]:
                    food_sources[i] = new_solution
                    fitness[i] = self._fitness(new_value)
                    trial[i] = 0
                else:
                    trial[i] += 1

            # Onlooker Bee Phase
            prob = fitness / np.sum(fitness)
            for i in range(self.n_bees):
                if np.random.rand() < prob[i]:
                    k = np.random.randint(0, self.n_bees)
                    while k == i:
                        k = np.random.randint(0, self.n_bees)
                    phi = np.random.uniform(-1, 1, self.n_dim)
                    new_solution = food_sources[i] + phi * (food_sources[i] - food_sources[k])
                    new_solution = np.clip(new_solution, self.lb, self.ub)
                    new_value = self.func(new_solution)
                    if self._fitness(new_value) > fitness[i]:
                        food_sources[i] = new_solution
                        fitness[i] = self._fitness(new_value)
                        trial[i] = 0
                    else:
                        trial[i] += 1

            # Scout Bee Phase
            for i in range(self.n_bees):
                if trial[i] > self.limit:
                    food_sources[i] = np.random.uniform(self.lb, self.ub, self.n_dim)
                    fitness[i] = self._fitness(self.func(food_sources[i]))
                    trial[i] = 0

            # Memorize best solution
            current_best_index = np.argmin([self.func(x) for x in food_sources])
            current_best_value = self.func(food_sources[current_best_index])
            if current_best_value < best_value:
                best_value = current_best_value
                best_solution = food_sources[current_best_index].copy()

            convergence_curve.append(best_value)
            print(f"Iteration {it+1}/{self.max_iter} — Best Value: {best_value:.6f}")

        return best_solution, best_value, convergence_curve

    def _fitness(self, value):
        if value >= 0:
            return 1 / (1 + value)
        else:
            return 1 + abs(value)

# ----------------------- Run Simulation ----------------------- #
if __name__ == "__main__":
    np.random.seed(42)
    abc = ArtificialBeeColony(func=sphere, n_dim=5, n_bees=40, limit=50, max_iter=200, lb=-5, ub=5)
    best_solution, best_value, curve = abc.optimize()

    print("\n===== Results =====")
    print("Best Solution:", best_solution)
    print("Best Objective Value:", best_value)

    # Plot Convergence Curve
    plt.plot(curve, 'r-', linewidth=2)
    plt.title("Convergence Curve of Artificial Bee Colony on Sphere Function")
    plt.xlabel("Iteration")
    plt.ylabel("Best Objective Value")
    plt.grid(True)
    plt.show()
# Out:
# Iteration 1/200 — Best Value: 16.376750
# Iteration 2/200 — Best Value: 4.611141
# Iteration 3/200 — Best Value: 4.611141
# Iteration 4/200 — Best Value: 0.506387
# Iteration 5/200 — Best Value: 0.506387
# Iteration 6/200 — Best Value: 0.506387
# Iteration 7/200 — Best Value: 0.506387
# Iteration 8/200 — Best Value: 0.506387
# Iteration 9/200 — Best Value: 0.506387
# Iteration 10/200 — Best Value: 0.506387
# Iteration 11/200 — Best Value: 0.506387
# Iteration 12/200 — Best Value: 0.506387
# Iteration 13/200 — Best Value: 0.506387
# Iteration 14/200 — Best Value: 0.506387
# Iteration 15/200 — Best Value: 0.506387
# Iteration 16/200 — Best Value: 0.494538
# Iteration 17/200 — Best Value: 0.494538
# Iteration 18/200 — Best Value: 0.494538
# Iteration 19/200 — Best Value: 0.494538
# Iteration 20/200 — Best Value: 0.346529
# Iteration 21/200 — Best Value: 0.337744
# Iteration 22/200 — Best Value: 0.337744
# Iteration 23/200 — Best Value: 0.201025
# Iteration 24/200 — Best Value: 0.201025
# Iteration 25/200 — Best Value: 0.090721
# Iteration 26/200 — Best Value: 0.090721
# Iteration 27/200 — Best Value: 0.090240
# Iteration 28/200 — Best Value: 0.090240
# Iteration 29/200 — Best Value: 0.090240
# Iteration 30/200 — Best Value: 0.090240
# Iteration 31/200 — Best Value: 0.090240
# Iteration 32/200 — Best Value: 0.022882
# Iteration 33/200 — Best Value: 0.022882
# Iteration 34/200 — Best Value: 0.017825
# Iteration 35/200 — Best Value: 0.017825
# Iteration 36/200 — Best Value: 0.017825
# Iteration 37/200 — Best Value: 0.017825
# Iteration 38/200 — Best Value: 0.017825
# Iteration 39/200 — Best Value: 0.017825
# Iteration 40/200 — Best Value: 0.017825
# Iteration 41/200 — Best Value: 0.017825
# Iteration 42/200 — Best Value: 0.017825
# Iteration 43/200 — Best Value: 0.005033
# Iteration 44/200 — Best Value: 0.005033
# Iteration 45/200 — Best Value: 0.005033
# Iteration 46/200 — Best Value: 0.005033
# Iteration 47/200 — Best Value: 0.005033
# Iteration 48/200 — Best Value: 0.000734
# Iteration 49/200 — Best Value: 0.000734
# Iteration 50/200 — Best Value: 0.000734
# Iteration 51/200 — Best Value: 0.000734
# Iteration 52/200 — Best Value: 0.000734
# Iteration 53/200 — Best Value: 0.000734
# Iteration 54/200 — Best Value: 0.000734
# Iteration 55/200 — Best Value: 0.000734
# Iteration 56/200 — Best Value: 0.000734
# Iteration 57/200 — Best Value: 0.000572
# Iteration 58/200 — Best Value: 0.000572
# Iteration 59/200 — Best Value: 0.000572
# Iteration 60/200 — Best Value: 0.000572
# Iteration 61/200 — Best Value: 0.000572
# Iteration 62/200 — Best Value: 0.000572
# Iteration 63/200 — Best Value: 0.000572
# Iteration 64/200 — Best Value: 0.000572
# Iteration 65/200 — Best Value: 0.000241
# Iteration 66/200 — Best Value: 0.000241
# Iteration 67/200 — Best Value: 0.000109
# Iteration 68/200 — Best Value: 0.000109
# Iteration 69/200 — Best Value: 0.000109
# Iteration 70/200 — Best Value: 0.000109
# Iteration 71/200 — Best Value: 0.000109
# Iteration 72/200 — Best Value: 0.000109
# Iteration 73/200 — Best Value: 0.000072
# Iteration 74/200 — Best Value: 0.000072
# Iteration 75/200 — Best Value: 0.000072
# Iteration 76/200 — Best Value: 0.000072
# Iteration 77/200 — Best Value: 0.000072
# Iteration 78/200 — Best Value: 0.000072
# Iteration 79/200 — Best Value: 0.000072
# Iteration 80/200 — Best Value: 0.000049
# Iteration 81/200 — Best Value: 0.000049
# Iteration 82/200 — Best Value: 0.000029
# Iteration 83/200 — Best Value: 0.000029
# Iteration 84/200 — Best Value: 0.000029
# Iteration 85/200 — Best Value: 0.000029
# Iteration 86/200 — Best Value: 0.000029
# Iteration 87/200 — Best Value: 0.000010
# Iteration 88/200 — Best Value: 0.000009
# Iteration 89/200 — Best Value: 0.000009
# Iteration 90/200 — Best Value: 0.000009
# Iteration 91/200 — Best Value: 0.000009
# Iteration 92/200 — Best Value: 0.000009
# Iteration 93/200 — Best Value: 0.000009
# Iteration 94/200 — Best Value: 0.000009
# Iteration 95/200 — Best Value: 0.000009
# Iteration 96/200 — Best Value: 0.000009
# Iteration 97/200 — Best Value: 0.000009
# Iteration 98/200 — Best Value: 0.000009
# Iteration 99/200 — Best Value: 0.000009
# Iteration 100/200 — Best Value: 0.000008
# Iteration 101/200 — Best Value: 0.000008
# Iteration 102/200 — Best Value: 0.000008
# Iteration 103/200 — Best Value: 0.000008
# Iteration 104/200 — Best Value: 0.000005
# Iteration 105/200 — Best Value: 0.000003
# Iteration 106/200 — Best Value: 0.000003
# Iteration 107/200 — Best Value: 0.000002
# Iteration 108/200 — Best Value: 0.000002
# Iteration 109/200 — Best Value: 0.000002
# Iteration 110/200 — Best Value: 0.000002
# Iteration 111/200 — Best Value: 0.000001
# Iteration 112/200 — Best Value: 0.000001
# Iteration 113/200 — Best Value: 0.000001
# Iteration 114/200 — Best Value: 0.000001
# Iteration 115/200 — Best Value: 0.000001
# Iteration 116/200 — Best Value: 0.000001
# Iteration 117/200 — Best Value: 0.000000
# Iteration 118/200 — Best Value: 0.000000
# Iteration 119/200 — Best Value: 0.000000
# Iteration 120/200 — Best Value: 0.000000
# Iteration 121/200 — Best Value: 0.000000
# Iteration 122/200 — Best Value: 0.000000
# Iteration 123/200 — Best Value: 0.000000
# Iteration 124/200 — Best Value: 0.000000
# Iteration 125/200 — Best Value: 0.000000
# Iteration 126/200 — Best Value: 0.000000
# Iteration 127/200 — Best Value: 0.000000
# Iteration 128/200 — Best Value: 0.000000
# Iteration 129/200 — Best Value: 0.000000
# Iteration 130/200 — Best Value: 0.000000
# Iteration 131/200 — Best Value: 0.000000
# Iteration 132/200 — Best Value: 0.000000
# Iteration 133/200 — Best Value: 0.000000
# Iteration 134/200 — Best Value: 0.000000
# Iteration 135/200 — Best Value: 0.000000
# Iteration 136/200 — Best Value: 0.000000
# Iteration 137/200 — Best Value: 0.000000
# Iteration 138/200 — Best Value: 0.000000
# Iteration 139/200 — Best Value: 0.000000
# Iteration 140/200 — Best Value: 0.000000
# Iteration 141/200 — Best Value: 0.000000
# Iteration 142/200 — Best Value: 0.000000
# Iteration 143/200 — Best Value: 0.000000
# Iteration 144/200 — Best Value: 0.000000
# Iteration 145/200 — Best Value: 0.000000
# Iteration 146/200 — Best Value: 0.000000
# Iteration 147/200 — Best Value: 0.000000
# Iteration 148/200 — Best Value: 0.000000
# Iteration 149/200 — Best Value: 0.000000
# Iteration 150/200 — Best Value: 0.000000
# Iteration 151/200 — Best Value: 0.000000
# Iteration 152/200 — Best Value: 0.000000
# Iteration 153/200 — Best Value: 0.000000
# Iteration 154/200 — Best Value: 0.000000
# Iteration 155/200 — Best Value: 0.000000
# Iteration 156/200 — Best Value: 0.000000
# Iteration 157/200 — Best Value: 0.000000
# Iteration 158/200 — Best Value: 0.000000
# Iteration 159/200 — Best Value: 0.000000
# Iteration 160/200 — Best Value: 0.000000
# Iteration 161/200 — Best Value: 0.000000
# Iteration 162/200 — Best Value: 0.000000
# Iteration 163/200 — Best Value: 0.000000
# Iteration 164/200 — Best Value: 0.000000
# Iteration 165/200 — Best Value: 0.000000
# Iteration 166/200 — Best Value: 0.000000
# Iteration 167/200 — Best Value: 0.000000
# Iteration 168/200 — Best Value: 0.000000
# Iteration 169/200 — Best Value: 0.000000
# Iteration 170/200 — Best Value: 0.000000
# Iteration 171/200 — Best Value: 0.000000
# Iteration 172/200 — Best Value: 0.000000
# Iteration 173/200 — Best Value: 0.000000
# Iteration 174/200 — Best Value: 0.000000
# Iteration 175/200 — Best Value: 0.000000
# Iteration 176/200 — Best Value: 0.000000
# Iteration 177/200 — Best Value: 0.000000
# Iteration 178/200 — Best Value: 0.000000
# Iteration 179/200 — Best Value: 0.000000
# Iteration 180/200 — Best Value: 0.000000
# Iteration 181/200 — Best Value: 0.000000
# Iteration 182/200 — Best Value: 0.000000
# Iteration 183/200 — Best Value: 0.000000
# Iteration 184/200 — Best Value: 0.000000
# Iteration 185/200 — Best Value: 0.000000
# Iteration 186/200 — Best Value: 0.000000
# Iteration 187/200 — Best Value: 0.000000
# Iteration 188/200 — Best Value: 0.000000
# Iteration 189/200 — Best Value: 0.000000
# Iteration 190/200 — Best Value: 0.000000
# Iteration 191/200 — Best Value: 0.000000
# Iteration 192/200 — Best Value: 0.000000
# Iteration 193/200 — Best Value: 0.000000
# Iteration 194/200 — Best Value: 0.000000
# Iteration 195/200 — Best Value: 0.000000
# Iteration 196/200 — Best Value: 0.000000
# Iteration 197/200 — Best Value: 0.000000
# Iteration 198/200 — Best Value: 0.000000
# Iteration 199/200 — Best Value: 0.000000
# Iteration 200/200 — Best Value: 0.000000
#
# ===== Results =====
# Best Solution: [ 1.27399428e-06  6.67965781e-07 -1.21959277e-07  7.12553731e-08
#  -2.95263478e-07]
# Best Objective Value: 2.1763716289300705e-12

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# -------------------------------
# Rastrigin Function (Minimization)
# -------------------------------
def rastrigin(x):
    return 10 * len(x) + sum([(xi ** 2 - 10 * np.cos(2 * np.pi * xi)) for xi in x])

# ----------------------------------
# Artificial Bee Colony Algorithm
# ----------------------------------
class ABC:
    def __init__(self, func, dim, lower_bound, upper_bound, num_bees=50, limit=100, max_iter=200):
        self.func = func
        self.dim = dim
        self.lower = lower_bound
        self.upper = upper_bound
        self.num_bees = num_bees
        self.limit = limit
        self.max_iter = max_iter
        self.food_sources = np.random.uniform(self.lower, self.upper, (num_bees, dim))
        self.fitness = np.array([self.calculate_fitness(fs) for fs in self.food_sources])
        self.trial = np.zeros(num_bees)
    
    def calculate_fitness(self, solution):
        value = self.func(solution)
        return 1 / (1 + value)  # Fitness inversely related to cost
    
    def employed_bee_phase(self):
        for i in range(self.num_bees):
            k = random.randint(0, self.num_bees - 1)
            while k == i:
                k = random.randint(0, self.num_bees - 1)
            phi = np.random.uniform(-1, 1, self.dim)
            new_solution = self.food_sources[i] + phi * (self.food_sources[i] - self.food_sources[k])
            new_solution = np.clip(new_solution, self.lower, self.upper)
            
            new_fit = self.calculate_fitness(new_solution)
            if new_fit > self.fitness[i]:
                self.food_sources[i] = new_solution
                self.fitness[i] = new_fit
                self.trial[i] = 0
            else:
                self.trial[i] += 1
    
    def onlooker_bee_phase(self):
        prob = self.fitness / np.sum(self.fitness)
        for i in range(self.num_bees):
            if random.random() < prob[i]:
                k = random.randint(0, self.num_bees - 1)
                while k == i:
                    k = random.randint(0, self.num_bees - 1)
                phi = np.random.uniform(-1, 1, self.dim)
                new_solution = self.food_sources[i] + phi * (self.food_sources[i] - self.food_sources[k])
                new_solution = np.clip(new_solution, self.lower, self.upper)
                
                new_fit = self.calculate_fitness(new_solution)
                if new_fit > self.fitness[i]:
                    self.food_sources[i] = new_solution
                    self.fitness[i] = new_fit
                    self.trial[i] = 0
                else:
                    self.trial[i] += 1
    
    def scout_bee_phase(self):
        for i in range(self.num_bees):
            if self.trial[i] > self.limit:
                self.food_sources[i] = np.random.uniform(self.lower, self.upper, self.dim)
                self.fitness[i] = self.calculate_fitness(self.food_sources[i])
                self.trial[i] = 0
    
    def optimize(self):
        best_values = []
        for iteration in range(self.max_iter):
            self.employed_bee_phase()
            self.onlooker_bee_phase()
            self.scout_bee_phase()
            
            best_index = np.argmax(self.fitness)
            best_value = self.func(self.food_sources[best_index])
            best_values.append(best_value)
            
            print(f"Iteration {iteration+1}: Best = {best_value:.6f}")
        
        best_solution = self.food_sources[np.argmax(self.fitness)]
        print("\nOptimal Solution:", best_solution)
        print("Optimal Value (Minimum):", self.func(best_solution))
        
        plt.plot(best_values)
        plt.title("ABC Algorithm Optimization Curve")
        plt.xlabel("Iteration")
        plt.ylabel("Best Fitness Value")
        plt.grid(True)
        plt.show()

# ----------------------------------
# Run the ABC Algorithm
# ----------------------------------
abc = ABC(func=rastrigin, dim=5, lower_bound=-5.12, upper_bound=5.12,
          num_bees=40, limit=50, max_iter=100)
abc.optimize()
# Out:
# Iteration 1: Best = 53.878962
# Iteration 2: Best = 38.392868
# Iteration 3: Best = 38.392868
# Iteration 4: Best = 38.392868
# Iteration 5: Best = 38.392868
# Iteration 6: Best = 14.164581
# Iteration 7: Best = 14.164581
# Iteration 8: Best = 14.164581
# Iteration 9: Best = 14.164581
# Iteration 10: Best = 14.164581
# Iteration 11: Best = 14.164581
# Iteration 12: Best = 14.164581
# Iteration 13: Best = 14.164581
# Iteration 14: Best = 14.164581
# Iteration 15: Best = 14.164581
# Iteration 16: Best = 14.164581
# Iteration 17: Best = 14.164581
# Iteration 18: Best = 14.164581
# Iteration 19: Best = 14.164581
# Iteration 20: Best = 14.164581
# Iteration 21: Best = 14.164581
# Iteration 22: Best = 14.164581
# Iteration 23: Best = 14.164581
# Iteration 24: Best = 14.164581
# Iteration 25: Best = 14.164581
# Iteration 26: Best = 14.164581
# Iteration 27: Best = 14.164581
# Iteration 28: Best = 14.164581
# Iteration 29: Best = 14.164581
# Iteration 30: Best = 14.164581
# Iteration 31: Best = 14.164581
# Iteration 32: Best = 14.164581
# Iteration 33: Best = 6.155669
# Iteration 34: Best = 6.155669
# Iteration 35: Best = 6.155669
# Iteration 36: Best = 6.155669
# Iteration 37: Best = 6.155669
# Iteration 38: Best = 6.155669
# Iteration 39: Best = 6.155669
# Iteration 40: Best = 6.155669
# Iteration 41: Best = 6.155669
# Iteration 42: Best = 6.155669
# Iteration 43: Best = 6.155669
# Iteration 44: Best = 6.155669
# Iteration 45: Best = 6.155669
# Iteration 46: Best = 6.155669
# Iteration 47: Best = 6.155669
# Iteration 48: Best = 6.155669
# Iteration 49: Best = 6.155669
# Iteration 50: Best = 6.155669
# Iteration 51: Best = 6.155669
# Iteration 52: Best = 6.155669
# Iteration 53: Best = 6.155669
# Iteration 54: Best = 6.155669
# Iteration 55: Best = 6.155669
# Iteration 56: Best = 6.155669
# Iteration 57: Best = 6.155669
# Iteration 58: Best = 6.155669
# Iteration 59: Best = 6.155669
# Iteration 60: Best = 6.155669
# Iteration 61: Best = 6.155669
# Iteration 62: Best = 6.155669
# Iteration 63: Best = 6.155669
# Iteration 64: Best = 6.155669
# Iteration 65: Best = 6.155669
# Iteration 66: Best = 6.155669
# Iteration 67: Best = 6.155669
# Iteration 68: Best = 6.155669
# Iteration 69: Best = 6.155669
# Iteration 70: Best = 4.085850
# Iteration 71: Best = 4.085850
# Iteration 72: Best = 4.085850
# Iteration 73: Best = 4.085850
# Iteration 74: Best = 4.085850
# Iteration 75: Best = 4.085850
# Iteration 76: Best = 4.085850
# Iteration 77: Best = 4.085850
# Iteration 78: Best = 4.085850
# Iteration 79: Best = 4.085850
# Iteration 80: Best = 4.085850
# Iteration 81: Best = 4.085850
# Iteration 82: Best = 4.085850
# Iteration 83: Best = 4.085850
# Iteration 84: Best = 4.085850
# Iteration 85: Best = 4.085850
# Iteration 86: Best = 4.085850
# Iteration 87: Best = 4.085850
# Iteration 88: Best = 4.085850
# Iteration 89: Best = 4.085850
# Iteration 90: Best = 4.085850
# Iteration 91: Best = 4.085850
# Iteration 92: Best = 4.085850
# Iteration 93: Best = 4.085850
# Iteration 94: Best = 4.085850
# Iteration 95: Best = 4.085850
# Iteration 96: Best = 4.085850
# Iteration 97: Best = 4.085850
# Iteration 98: Best = 4.085850
# Iteration 99: Best = 4.085850
# Iteration 100: Best = 4.085850
#
# Optimal Solution: [-0.98551481  1.04718146  0.01465735  0.02642926  1.03790832]
# Optimal Value (Minimum): 4.085850066096796
